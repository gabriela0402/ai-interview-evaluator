# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriela0402/ai-interview-evaluator/blob/main/notebooks/00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Interview Evaluator — Setup
#
# Este notebook prepara o ambiente inicial do projeto.
#
# Nesta etapa, vamos apenas instalar as bibliotecas e verificar se o Colab está funcionando.

# %%
# %pip install -q openai pandas pydantic python-dotenv scikit-learn matplotlib seaborn

# %%
import sys
import pandas as pd
import sklearn

print(f"Python: {sys.version.split()[0]}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print("Ambiente configurado com sucesso!")
# Out:
# Python: 3.13.15
# Pandas: 2.2.3
# Scikit-learn: 1.6.1
# Ambiente configurado com sucesso!
